# %% [markdown]
# ##### 获得中证股票市盈率TTM，用于/home/ts/app/AiStock/--市场状态量化系统.ipynb

# %%
import akshare as ak
from sqlalchemy import create_engine
import pandas as pd
from tqdm import tqdm

# %%
engPE = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/csiIndexPE')
engI = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/tdxIndex')

# %%
indexList = ['000300', '000905', '000852', '932000','399311','931071', '932042', '932419','930851', '930902', '931495','932359','931585', '931726','931772', '931687', '931798','931746', '931229', '931897','931152', '931992', '931166','930716', '930725',  '931465','930707', '930662', '930910','930635','000917', '000937', '931549','931463', '930606','930838','930901', '931480', '931580', '930781']

# %%
indexList = ['931866','931865','931140']

# %%
indexList = ['932044','931893','932394']

# %%
930599 930850 931087 399812 931235 000949 930955 932047  932039 931231 931066  931588

# %%
len(indexList)
# Out:
# 3

# %%
ls = []
for code in tqdm(indexList):
    try:
        df_tmp = ak.stock_zh_index_hist_csindex(code,start_date="20200101", end_date="20290101")
        df_tmp.to_sql(code, engPE, if_exists='replace', index=False)
    except:
        print(code)
        ls.append(code)
# Out:
# ...
# 100%|██████████| 3/3 [00:02<00:00,  1.48it/s]

# %%
ls
# Out:
# []

# %%
ak.stock_zh_index_hist_csindex('930599',start_date="20200101", end_date="20290101")
# Out:
#               日期    指数代码      指数中文全称 指数中文简称  \
# 0     2020-01-01  930599  中证高端装备制造指数   中证高装
# 1     2020-01-02  930599  中证高端装备制造指数   中证高装
# 2     2020-01-03  930599  中证高端装备制造指数   中证高装
# 3     2020-01-06  930599  中证高端装备制造指数   中证高装
# 4     2020-01-07  930599  中证高端装备制造指数   中证高装
# ...          ...     ...         ...    ...
# 1483  2026-02-11  930599  中证高端装备制造指数   中证高装
# 1484  2026-02-12  930599  中证高端装备制造指数   中证高装
# 1485  2026-02-13  930599  中证高端装备制造指数   中证高装
# 1486  2026-02-24  930599  中证高端装备制造指数   中证高装
# 1487  2026-02-25  930599  中证高端装备制造指数   中证高装
#
#                                           指数英文全称                  指数英文简称  \
# 0     CSI High-End Equipment Manufacturing Index  CSI High-End Equipment
# 1     CSI High-End Equipment Manufacturing Index  CSI High-End Equipment
# 2     CSI High-End Equipment Manufacturing Index  CSI High-End Equipment
# 3     CSI High-End Equipment Manufacturing Index  CSI High-End Equipment
# ...

# %%
df = pd.read_sql('399311', engI)

# %%
df['return_1d'] = df['close'].pct_change()

# %%
import numpy as np

# %%
df['return_1d'].rolling(20).std() * np.sqrt(250)
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 5104    0.156710
# 5105    0.153289
# 5106    0.153324
# 5107    0.154190
# 5108    0.160941
# Name: return_1d, Length: 5109, dtype: float64

# %% [markdown]
# ##### 获得中证股票市盈率TTM，用于/home/ts/app/AiStock/--市场状态量化系统.ipynb

# %%
import akshare as ak
from sqlalchemy import create_engine
import pandas as pd
from tqdm import tqdm

# %%
engPE = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/csiIndexPE')
engI = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/tdxIndex')

# %%
indexList1 = ['000300', '000905', '000852', '932000','399311','931071', '932042', '932419','930851', '930902', '931495','932359','931585', '931726','931772', '931687', '931798','931746', '931229', '931897','931152', '931992', '931166','930716', '930725',  '931465','930707', '930662', '930910','930635','000917', '000937', '931549','931463', '930606','930838','930901', '931480', '931580', '930781']

# %%
indexList = ['000300','000905','000852','932000',
    '932042','931865','930850','931866','930599',
    '931087','930851','930902','931495','931585',
    '931798','931772','931897','931687','931746',
    '931140','931152','931992','931166','399812',
    '931465','931235','930716','930725',
    '930910','930707','930662','000949',
    '000917','000937','930955','932047',
    '932039','931231','930838','931463',
    '931066','931480','930901','930781','931588']

# %%
indexList = ['931066', '931480', '930901', '930781', '931588']

# %%
ls = []
for code in tqdm(indexList):
    try:
        df_tmp = ak.stock_zh_index_hist_csindex(code,start_date="20200101", end_date="20290101")
        df_tmp.to_sql(code, engPE, if_exists='replace', index=False)
    except:
        print(code)
        ls.append(code)
# Out:
# 100%|██████████| 5/5 [00:04<00:00,  1.15it/s]

# %%
ls

# %%
ak.stock_zh_index_hist_csindex('399812',start_date="20200101", end_date="20290101")
# Out:
#               日期    指数代码    指数中文全称 指数中文简称                      指数英文全称  \
# 0     2020-01-01  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
# 1     2020-01-02  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
# 2     2020-01-03  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
# 3     2020-01-06  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
# 4     2020-01-07  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
# ...          ...     ...       ...    ...                         ...
# 1484  2026-02-12  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
# 1485  2026-02-13  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
# 1486  2026-02-24  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
# 1487  2026-02-25  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
# 1488  2026-02-26  399812  中证养老产业指数   养老产业  CSI Old-Age Industry Index
#
#                     指数英文简称       开盘       最高       最低       收盘      涨跌   涨跌幅  \
# ...

# %%
df = pd.read_sql('399311', engI)

# %%
df['return_1d'] = df['close'].pct_change()

# %%
import numpy as np

# %%
df['return_1d'].rolling(20).std() * np.sqrt(250)

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import plotly.express as px
from tqdm import tqdm

# %%
df = pd.read_excel('/home/ts/app/AnaStock/MergIndex.xlsx').set_index('datetime')

# %%
import streamlit as st
from streamlit_option_menu import option_menu
# Out:
# 2024-09-18 11:02:03.998 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
with st.sidebar:
    selected = option_menu("Main Menu", ["Home", 'Settings'], 
        icons=['house', 'gear'], menu_icon="cast", default_index=1)
    selected
# Out:
# 2024-09-18 11:02:43.695 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-18 11:02:43.696 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-18 11:02:43.696 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2024-09-18 11:02:43.697 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-18 11:02:43.748
# ...
#   command:
#
#     streamlit run /home/ts/Jupyter/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# ...

# %%
streamlit run menutest.ipynb
# Out:
#   Cell In[5], line 1
#     streamlit run menutest.ipynb
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# 5' K线(0)1D48 5D240 8D384 13D624 bar , 1'K线(8)1D240 2D480 3D720 bar, 日K线(9)
# 每次800   0SZ  1SH  ======= 在线分析

# %%
from pytdx.hq import TdxHq_API
import pandas as pd
import plotly.express as px

import numpy as np 

api = TdxHq_API()

# %%
api.connect('121.36.81.195', 7709)

# %% [markdown]
# 个股

# %%
df3 = api.to_df(api.get_security_bars(8, 0, '000001', 0, 720))
df5 = api.to_df(api.get_security_bars(0, 0, '000001', 0, 240))
df13 = api.to_df(api.get_security_bars(0, 0, '000001', 0, 624))
df21 = api.to_df(api.get_security_bars(9, 0, '000001', 0, 21))
df55 = api.to_df(api.get_security_bars(9, 0, '000001', 0, 55))
df144 = api.to_df(api.get_security_bars(9, 0, '000001', 0, 144))

# %%
df1 = api.to_df(api.get_index_bars(8, 1, '000001', 0, 800))
df1 = api.to_df(api.get_index_bars(0, 1, '000001', 0, 624))

# %%
def norm(df, column_name,n):
    min_val = df[column_name].min()
    max_val = df[column_name].max()
    normalized_column = (df[column_name] - min_val) / (max_val - min_val)
    scaled_column = normalized_column * (n - 1) + 1
    discrete_scaled_column = scaled_column.round().astype(int)
    return discrete_scaled_column

# %%
lsDF = [df3,df5,df13,df21,df55,df144]
lsD = ['3D','5D',"13D","21D","55D","144D"]
con = [720,240,624,21,55,144]
plDF = pd.DataFrame()

# %%
for n, df in enumerate(lsDF):
    weights = norm(df,'amount',con[n])
    weighted_data = np.repeat(df['close'], repeats=weights)
    dDF = pd.DataFrame(weighted_data)
    dDF['周期'] = lsD[n]
    plDF = pd.concat([plDF,dDF])

# %%
# fig = px.box(plDF,y='close',facet_col='周期',facet_col_spacing=0.02,boxmode='overlay')
fig = px.violin(plDF,y='close',facet_col='周期',facet_col_spacing=0.03,box=True,violinmode='overlay')
fig.show()
# Out:
# <div>                            <div id="19aad0a9-e6ab-4215-a224-a02a331e3383" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19aad0a9-e6ab-4215-a224-a02a331e3383")) {                    Plotly.newPlot(                        "19aad0a9-e6ab-4215-a224-a02a331e3383",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"周期=3D\u003cbr\u003eclose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","scalegroup":"True","showlegend":false,"x0":" ","xaxis":"x","y":[13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,13.1,
# ...

# %% [markdown]
# ====================

# %%
plDF

# %%
weights1 = norm(df1,'amount',)
weighted_data1 = np.repeat(df1['close'], repeats=weights1)
ddf1 = pd.DataFrame(weighted_data1)

# %%
ddf1['class'] = 'a'

# %%
ddf2

# %%
weights2 = norm(df2,'amount')
weighted_data2 = np.repeat(df2['close'], repeats=weights2)
ddf2 = pd.DataFrame(weighted_data2)
ddf2['class'] = 'b'

# %%
dff3 = ddf2.copy()
dff3['class'] = 'c'

# %%
dff3

# %%
dff = pd.concat([ddf2,dff3]).reset_index(drop=True)

# %%
dff

# %%
fig = px.violin(dff,y='close',facet_col='class',box=True)
fig.show()

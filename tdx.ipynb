# %% [markdown]
# 5' K线(0)1D48 5D240 8D384 13D624 bar , 1'K线(8)1D240 2D480 3D720 bar, 日K线(9)
# 每次800   0SZ  1SH  ======= 在线分析

# %%
from pytdx.hq import TdxHq_API
from pytdx.exhq import TdxExHq_API
import pandas as pd
import plotly.express as px

import numpy as np

# %%
eapi =  TdxExHq_API()
api = TdxHq_API()

# %%
eapi.connect('47.112.95.207', 7720)

# %%
api.connect('121.36.81.195', 7709)

# %%
df1 = api.to_df(api.get_index_bars(8, 1, '000001', 0, 800))

# %%
df2 = api.to_df(api.get_security_bars(8, 0, '000001', 0, 720))

# %%
df1 = api.to_df(api.get_index_bars(0, 1, '000001', 0, 624))
df2 = api.to_df(api.get_security_bars(0, 0, '000001', 0, 624))

# %%
df2
# Out:
#       open  close   high    low         vol       amount  year  month  day  \
# 0     9.65   9.67   9.67   9.61   5489500.0   52908288.0  2024      9   12
# 1     9.67   9.66   9.68   9.63   2821500.0   27244360.0  2024      9   12
# 2     9.66   9.66   9.67   9.64   2160700.0   20865328.0  2024      9   12
# 3     9.66   9.68   9.68   9.66   1801000.0   17410184.0  2024      9   12
# 4     9.68   9.69   9.69   9.66   1839500.0   17799418.0  2024      9   12
# ..     ...    ...    ...    ...         ...          ...   ...    ...  ...
# 619  11.88  11.86  11.88  11.83   6807000.0   80734776.0  2024     10    9
# 620  11.85  11.79  11.87  11.78   7876000.0   93108384.0  2024     10    9
# 621  11.79  11.73  11.80  11.72  11204700.0  131740152.0  2024     10    9
# 622  11.72  11.69  11.75  11.69  16294300.0  190954080.0  2024     10    9
# 623  11.70  11.68  11.70  11.66  10185600.0  118968192.0  2024     10    9
#
#      hour  minute          datetime
# ...

# %%
def norm(df, column_name):
    min_val = df[column_name].min()
    max_val = df[column_name].max()
    normalized_column = (df[column_name] - min_val) / (max_val - min_val)
    scaled_column = normalized_column * (624 - 1) + 1
    discrete_scaled_column = scaled_column.round().astype(int)
    return discrete_scaled_column

# %%
weights = norm(df2,'amount')
weighted_data = np.repeat(df2['close'], repeats=weights)

# %%
n = [5,21,55]
n =5
weights = norm(df1.tail(n),'amount')
weighted_data = np.repeat(df['close'].tail(n), repeats=weights)

# %%
fig = px.violin(weighted_data,box=True)
fig.show()
# Out:
# <div>                            <div id="fc1c451a-2977-4a99-87ac-e44722036dde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc1c451a-2977-4a99-87ac-e44722036dde")) {                    Plotly.newPlot(                        "fc1c451a-2977-4a99-87ac-e44722036dde",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"variable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","scalegroup":"True","showlegend":false,"x":["close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","clo
# ...

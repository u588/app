# %%
from pytdx.hq import TdxHq_API
from pytdx.exhq import TdxExHq_API
import pandas as pd

# %%
eapi =  TdxExHq_API()
api = TdxHq_API()

# %%
sh = tdxIndexs[tdxIndexs['MarketCode'] == 1 ]
sz = tdxIndexs[tdxIndexs['MarketCode'] == 0 ]
zz = tdxIndexs[tdxIndexs['MarketCode'] == 62 ]

# %%
eapi.connect('47.112.95.207', 7720)

# %%
api.connect('121.36.81.195', 7709)

# %%
api.to_df(api.get_index_bars(9, 1, '000001', 0, 3))
# Out:
#       open    close     high      low         vol        amount  year  month  \
# 0  3194.72  3336.50  3358.59  3153.70  11023379.0  1.167773e+12  2024      9
# 1  3674.40  3489.78  3674.40  3372.19  13134602.0  1.510513e+12  2024     10
# 2  3427.22  3258.86  3437.16  3249.16   9927572.0  1.264311e+12  2024     10
#
#    day  hour  minute          datetime  up_count  down_count
# 0   30    15       0  2024-09-30 15:00      2301           2
# 1    8    15       0  2024-10-08 15:00      2128         168
# 2    9    15       0  2024-10-09 15:00       120        2181

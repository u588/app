# %% [markdown]
# 5' K线(0)1D48 5D240 8D384 13D624 bar , 1'K线(8)1D240 2D480 3D720 bar, 日K线(9)
# 每次800   0SZ  1SH  ======= 在线分析

# %%
from pytdx.hq import TdxHq_API
import pandas as pd
import plotly.express as px

import numpy as np 

api = TdxHq_API()

# %%
api.connect('121.36.81.195', 7709)

# %%
df750 = api.to_df(api.get_index_bars(9, 1, '000001', 10, 799))

# %%
api.to_df(api.get_index_bars(9, 1, '000001', 10, 799))

# %%
df750

# %% [markdown]
# 个股

# %%
df3 = api.to_df(api.get_security_bars(8, 0, '000001', 0, 720))
df5 = api.to_df(api.get_security_bars(0, 0, '000001', 0, 240))
df13 = api.to_df(api.get_security_bars(0, 0, '000001', 0, 624))
df21 = api.to_df(api.get_security_bars(9, 0, '000001', 0, 21))
df55 = api.to_df(api.get_security_bars(9, 0, '000001', 0, 55))
df144 = api.to_df(api.get_security_bars(9, 0, '000001', 0, 144))

# %% [markdown]
# 指数

# %%
df3 = api.to_df(api.get_index_bars(8, 1, '000001', 0, 720))
df5 = api.to_df(api.get_index_bars(0, 1, '000001', 0, 240))
df13 = api.to_df(api.get_index_bars(0, 1, '000001', 0, 624))
df21 = api.to_df(api.get_index_bars(9, 1, '000001', 0, 21))
df55 = api.to_df(api.get_index_bars(9, 1, '000001', 0, 55))
df144 = api.to_df(api.get_index_bars(9, 1, '000001', 0, 144))

# %%
lsDF = [df3,df5,df13,df21,df55,df144]
lsD = ['3D','5D',"13D","21D","55D","144D"]
con = [720,240,624,21,55,144]

# %% [markdown]
# 加权

# %%
def norm(df, column_name,n):
    min_val = df[column_name].min()
    max_val = df[column_name].max()
    normalized_column = (df[column_name] - min_val) / (max_val - min_val)
    scaled_column = normalized_column * (n - 1) + 1
    discrete_scaled_column = scaled_column.round().astype(int)
    return discrete_scaled_column

# %%
plDF = pd.DataFrame()
for n, df in enumerate(lsDF):
    weights = norm(df,'vol',con[n])
    weighted_data = np.repeat(df['close'], repeats=weights)
    dDF = pd.DataFrame(weighted_data)
    dDF['周期'] = lsD[n]
    plDF = pd.concat([plDF,dDF])

# %%
df

# %%
fig = px.violin(plDF,y='close',facet_col='周期',facet_col_spacing=0.01,box=True,violinmode='overlay')
fig.show()

# %%
fig = px.box(plDF,y='close',facet_col='周期',facet_col_spacing=0.03,boxmode='group')
fig.show()

# %% [markdown]
# 价格

# %%
plDF = pd.DataFrame()
for n, df in enumerate(lsDF):
    # weights = norm(df,'amount',con[n])
    # weighted_data = np.repeat(df['close'], repeats=weights)
    dDF = pd.DataFrame(df['close'])
    dDF['周期'] = lsD[n]
    plDF = pd.concat([plDF,dDF])

# %%
fig = px.violin(plDF,y='close',facet_col='周期',facet_col_spacing=0.03,box=True,violinmode='overlay',title='价格')
fig.show()

# %%
fig = px.box(plDF,y='close',facet_col='周期',facet_col_spacing=0.03,boxmode='group',title='价格')
fig.show()

# %% [markdown]
# 数量

# %%
plDF = pd.DataFrame()
for n, df in enumerate(lsDF):
    dDF = pd.DataFrame(df['amount'])
    dDF['周期'] = lsD[n]
    plDF = pd.concat([plDF,dDF])

# %%
fig = px.violin(plDF[plDF['周期'].isin(['21D','55D','144D'])],y='amount',facet_col='周期',facet_col_spacing=0.03,box=True,violinmode='overlay',title='数量')
fig.show()

# %%
fig = px.violin(plDF,y='amount',facet_col='周期',facet_col_spacing=0.03,box=True,violinmode='overlay',title='数量')
fig.show()

# %%
fig = px.box(plDF,y='amount',facet_col='周期',facet_col_spacing=0.03,boxmode='group',title='数量')
fig.show()

# %%
fig = px.violin(df3,y='vol',x='minute',box=True,violinmode='group',title='数量')
fig.show()

# %%
fig = px.box(df3,y='vol',x='minute',boxmode='group',title='数量')
fig.show()

# %%
fig = px.density_contour(df3, y="hour",x='minute',z='amount',histfunc='sum',nbinsx=60,nbinsy=4)
fig.update_traces(contours_coloring="fill", contours_showlabels = True)

fig.show()

# %%
fig = px.density_contour(df3, y="day",x='hour',z='amount',nbinsx=4,nbinsy=3, histfunc='sum')

fig.update_traces(contours_coloring="fill", contours_showlabels = True)
fig.show()

# %%
fig = px.density_contour(df3, y="day",x='minute',z='amount',nbinsx=60,nbinsy=3, histfunc='sum')

fig.update_traces(contours_coloring="fill", contours_showlabels = True)
fig.show()

# %%
fig = px.density_heatmap(df3, x='minute',y='hour',z='amount',histfunc='sum',histnorm='percent' ,nbinsx=60,nbinsy=7)
fig.show()

# %%
fig = px.density_heatmap(df3, x='minute',y='day',z='amount',histfunc='sum',histnorm='percent' ,nbinsx=60,nbinsy=3)
fig.show()

# %%
fig = px.density_heatmap(df3, x='hour',y='day',z='amount',histfunc='sum',histnorm='percent' ,nbinsx=7,nbinsy=3)
fig.show()

# %%
fig = px.density_heatmap(df5, x='minute',y='day',z='amount',histfunc='sum',histnorm='percent' ,nbinsx=20,nbinsy=4)
fig.show()

# %%
fig = px.density_contour(df3, y="day",x='minute',z='vol',nbinsx=60,nbinsy=3, histfunc='sum')
# fig = px.density_contour(df3, y="hour",x='minute',z='vol',nbinsx=60,nbinsy=4, histfunc='sum')
# fig.update_traces(contours_coloring="fill", contours_showlabels = True)
fig.show()

# %% [markdown]
# ==== 参数 --histfunc: 'count', 'sum', 'avg', 'min', or 'max'   --histnorm: 'percent', 'probability', 'density', or 'probability density'

# %%
import pandas as pd
from sqlalchemy import create_engine
eng = create_engine('postgresql+psycopg2://sa:11111111@10.3.18.56/tdxIndex')

# %%
idxDF = pd.read_sql('000001', eng)

# %%
# ,marginal_x="histogram", marginal_y="histogram"
fig = px.density_heatmap(idxDF[(idxDF['year']>2000) & (idxDF['year']<2025) ], x='day',y='month',z='amount',histfunc='min',histnorm='percent',nbinsx=35,nbinsy=12,text_auto='.2r')
fig.show()

# %%
fig = px.density_heatmap(idxDF, x='month',y='year',z='amount',histfunc='avg',histnorm='percent',nbinsx=12,nbinsy=50,text_auto='.2f')
fig.show()

# %%
fig = px.density_heatmap(df13, x='minute',y='hour',z='amount',histfunc='max',histnorm='percent' ,nbinsx=60,nbinsy=8,text_auto='.2')
fig.show()

# %%
szDF = pd.read_sql('000001', eng)
kc50DF = pd.read_sql('000688', eng)
hs300DF = pd.read_sql('000300', eng)
hc100DF = pd.read_sql('000698', eng)
scDF = pd.read_sql('399001', eng)

# %%
plData = pd.DataFrame()

# %%
plData['datetime'] = hc100DF.tail(1150)['datetime'].reset_index(drop=True)

# %%
plData['上证指数'] = szDF.tail(1150)['close'].reset_index(drop=True)
plData['深证成指'] = scDF.tail(1150)['close'].reset_index(drop=True)
plData['沪深300'] = hs300DF.tail(1150)['close'].reset_index(drop=True)
plData['科创50'] = kc50DF.tail(1150)['close'].reset_index(drop=True)
plData['科创100'] = hc100DF.tail(1150)['close'].reset_index(drop=True)

# %%
def normalize(x):
    return (x - x.min()) / (x.max() - x.min())

# %%
ddd = plData.set_index('datetime').apply(normalize, axis=0)

# %%
fig = px.line(ddd.reset_index(),x='datetime', y=plData.columns,line_shape='linear')
# fig = px.area(ddd.reset_index(),x='datetime', y=plData.columns)
fig.show(config={'scrollZoom': True,'displaylogo':False})
# Out:
# <div>                            <div id="93eccc38-d945-4cab-b650-c5f7923ccc4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93eccc38-d945-4cab-b650-c5f7923ccc4c")) {                    Plotly.newPlot(                        "93eccc38-d945-4cab-b650-c5f7923ccc4c",                        [{"hovertemplate":"variable=上证指数\u003cbr\u003edatetime=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"上证指数","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"上证指数","showlegend":true,"x":["2020-01-08 15:00","2020-01-09 15:00","2020-01-10 15:00","2020-01-13 15:00","2020-01-14 15:00","2020-01-15 15:00","2020-01-16 15:00","2020-01-17 15:00","2020-01-20 15:00","2020-01-21 15:00","2020-01-22 15:00","2020-01-23 15:00","2020-02-03 15:00","2020-02-04 15:00","2020-02-05 15:00","2020-02-06 15:00","2020-02-07 15:00","2020-02-10 15:00","2020-02-11 15:00","2020-02-12 15:00","2020-02-13 15:00","2020-02-14 15:00","2020-02-17 15:00","2020-02-18 15:00","2020-02-19 15:00","2020-02-20 15:00","2020-02-21 15:00","2020-02-24 15:00","2020-02-25 15:00","2020-02-26 15:00","2020-02-27 15:00","2020-02-28 15:00","2020-03-02 15:00","2020-03-03 15:00","2020-03-04 15:00","2020-03-05 15:00","2020-03-06 15:00","2020-03-09 15:00","2020-03-10 15:00","2020-03-11 15:00","2020-03-12 15
# %%
import pandas as pd
from sqlalchemy import create_engine
import plotly.express as px

# %%
engI = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/tdxIndex')

# %%
eng = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/tdxStocks')

# %%
dfi = pd.read_sql('000001',engI)

# %%
def pct(df,n,m):
    dff = df.copy()
    dff.set_index('datetime', inplace=True)
    dff['PCT21'] = dff['close'].pct_change(n)
    dff = dff[dff['PCT21']>m]
    return(dff)

# %%
pct1 = pct(dfi,21,0.1)
fig = px.scatter(pct1,y='close',hover_name=pct1.index)
fig.update_layout(title=str(pct1.shape[0]))
fig.show()
# Out:
# <div>                            <div id="736bd843-bc4a-40ea-a28e-09e9d966941d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("736bd843-bc4a-40ea-a28e-09e9d966941d")) {                    Plotly.newPlot(                        "736bd843-bc4a-40ea-a28e-09e9d966941d",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003edatetime=%{x}\u003cbr\u003eclose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["2000-01-27 15:00","2000-01-28 15:00","2000-02-14 15:00","2000-02-15 15:00","2000-02-16 15:00","2000-02-17 15:00","2000-02-18 15:00","2000-02-21 15:00","2000-02-24 15:00","2000-02-25 15:00","2000-02-28 15:00","2000-02-29 15:00","2000-03-01 15:00","2000-03-02 15:00","2000-03-03 15:00",
# ...

# %%
dfz = pd.read_sql('399001',engI)
pctz = pct(dfz,21,0.1)
fig = px.scatter(pctz,y='close',hover_name=pctz.index)
fig.update_layout(title=str(pctz.shape[0]))
fig.show()
# Out:
# <div>                            <div id="ce4cd3c8-faf8-4b6b-98b1-4bd001f657ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce4cd3c8-faf8-4b6b-98b1-4bd001f657ab")) {                    Plotly.newPlot(                        "ce4cd3c8-faf8-4b6b-98b1-4bd001f657ab",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003edatetime=%{x}\u003cbr\u003eclose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["2000-01-10 15:00","2000-01-25 15:00","2000-01-26 15:00","2000-01-27 15:00","2000-01-28 15:00","2000-02-14 15:00","2000-02-15 15:00","2000-02-16 15:00","2000-02-17 15:00","2000-02-18 15:00","2000-02-21 15:00","2000-02-24 15:00","2000-02-25 15:00","2000-02-28 15:00","2000-02-29 15:00",
# ...

# %%
dfp = pd.read_sql('600409',eng)
pctp = pct(dfp,21,0.3)
fig = px.scatter(pctp,y='close',hover_name=pctp.index)
fig.update_layout(title=str(pctp.shape[0]))
# fig.update_xaxes(dtick='D',tickformat='%Y-%m-%d')
fig.show()
# Out:
# <div>                            <div id="5a728a24-8c3c-4fcc-b4f6-0ce92db35856" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a728a24-8c3c-4fcc-b4f6-0ce92db35856")) {                    Plotly.newPlot(                        "5a728a24-8c3c-4fcc-b4f6-0ce92db35856",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003edatetime=%{x}\u003cbr\u003eclose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["2007-03-15 15:00","2007-03-26 15:00","2007-03-28 15:00","2007-04-27 15:00","2007-04-30 15:00","2007-05-09 15:00","2007-05-10 15:00","2007-05-11 15:00","2007-05-14 15:00","2007-05-15 15:00","2007-05-16 15:00","2007-05-17 15:00","2007-05-18 15:00","2007-05-21 15:00","2007-05-22 15:00",
# ...

# %%
pctp.shape[0]
# Out:
# 277

# %%
def norm(df):
    min_value = df.min()
    max_value = df.max()
    nor = (df - min_value) / (max_value - min_value)
    return(nor)

# %%
dfz
# Out:
#               datetime      open     close       high       low         vol  \
# 0     1999-11-10 15:00   3751.75   3711.79   3751.750   3671.09     64469.0
# 1     1999-11-11 15:00   3709.64   3702.33   3737.700   3678.30     46864.0
# 2     1999-11-12 15:00   3696.73   3705.16   3728.960   3692.37     36247.0
# 3     1999-11-15 15:00   3702.87   3678.99   3707.440   3643.18     59827.0
# 4     1999-11-16 15:00   3699.95   3622.83   3728.690   3610.95     87654.0
# ...                ...       ...       ...        ...       ...         ...
# 6074  2024-12-05 15:00  10565.03  10634.49  10674.769  10565.03   8446637.0
# 6075  2024-12-06 15:00  10642.89  10791.34  10860.250  10618.76  10293404.0
# 6076  2024-12-09 15:00  10780.98  10731.66  10821.509  10668.33   9551560.0
# 6077  2024-12-10 15:00  11124.78  10812.58  11134.550  10792.01  11713880.0
# 6078  2024-12-11 15:00  10781.10  10848.42  10884.060  10781.08  10122728.0
#
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=dfz.datetime, y=norm(dfz['close']),hovertext=dfz['close'], mode='lines', name='数据集 0'))
fig.add_trace(go.Scatter(x=pctz.index, y=norm(pctz['close']),hovertext=pctz['close'], mode='markers', name='数据集 0.1', marker=dict(color='blue')))
fig.add_trace(go.Scatter(x=dfp.datetime, y=norm(dfp['close']),hovertext=dfp['close'], mode='lines', name='数据集 0'))
fig.add_trace(go.Scatter(x=pctp.index, y=norm(pctp['close']),hovertext=pctp['close'], mode='markers', name='数据集 0.25', marker=dict(color='red')))

# 添加标题和轴标签
# fig.update_layout(
#     title="多列散点图",  # 图表标题
#     xaxis_title="X 轴标签",  # X 轴标签
#     yaxis_title="Y 轴标签"   # Y 轴标签
# )

# # 显示图表
fig.show(config={'scrollZoom':True})
# Out:
# <div>                            <div id="618680a1-d457-42c2-992f-85a9b47d5f71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("618680a1-d457-42c2-992f-85a9b47d5f71")) {                    Plotly.newPlot(                        "618680a1-d457-42c2-992f-85a9b47d5f71",                        [{"hovertext":[3711.79,3702.33,3705.16,3678.99,3622.83,3689.42,3746.06,3695.93,3660.24,3676.59,3630.85,3598.56,3597.54,3545.89,3533.98,3559.85,3524.85,3522.68,3492.5,3499.83,3486.14,3457.33,3516.38,3484.88,3498.4,3595.92,3535.82,3481.27,3415.6,3399.34,3357.37,3326.09,3299.89,3304.86,3342.4,3369.61,3497.06,3486.28,3655.19,3829.89,3921.48,3716.78,3605.82,3580.98,3542.82,3594.64,3571.97,3603.85,3668.84,3702.08,3734.72,3726.05,3737.98,3844.96,3952.4,4322.37,4394.69,44
# ...

# %%
figv = px.violin(pctp['close'], box=True)
figv.show()
# Out:
# <div>                            <div id="7a51d212-1330-49ad-a7a7-035ed39c8cc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a51d212-1330-49ad-a7a7-035ed39c8cc3")) {                    Plotly.newPlot(                        "7a51d212-1330-49ad-a7a7-035ed39c8cc3",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"variable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","scalegroup":"True","showlegend":false,"x":["close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","close","clo
# ...

# %%
figh = px.histogram(pctp,x='close',marginal='rug',nbins=50)
figh.show()
# Out:
# <div>                            <div id="cbc9bbd6-ca11-4dae-8a91-5871835f252b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbc9bbd6-ca11-4dae-8a91-5871835f252b")) {                    Plotly.newPlot(                        "cbc9bbd6-ca11-4dae-8a91-5871835f252b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"close=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[7.09,7.42,7.12,9.09,9.35,10.29,10.36,11.02,12.12,11.58,12.4,12.41,12.03,12.25,12.2,13.09,12.67,12.66,12.73,13.06,10.91,14.4,14.41,16.01,15.93,17.07,16.75,17.29,16.21,16.53,17.31,16.7,1
# ...

# %%
import pandas as pd
from pytdx.hq import TdxHq_API
from pytdx.crawler.history_financial_crawler import HistoryFinancialListCrawler
from pytdx.crawler.history_financial_crawler import HistoryFinancialCrawler
from pytdx.crawler.base_crawler import demo_reporthook

# %%
crawler = HistoryFinancialListCrawler()
list_data = crawler.fetch_and_parse()
print(pd.DataFrame(data=list_data).head(30))
# Out:
#             filename                              hash  filesize
# 0   gpcw20261231.zip  2ccefe15457fe73f9107c49b79714854       164
# 1   gpcw20260930.zip  5269be5247dd0f8dc26c5e5415b39096       164
# 2   gpcw20260630.zip  cfff4ae88640504ece1d2d204b13a39c       164
# 3   gpcw20260331.zip  e31e2fa50e0292078b6f4c42c001ecab       165
# 4   gpcw20251231.zip  0cd2fb520c09e059b5cd124229a724eb       164
# 5   gpcw20250930.zip  b1e400c8fb1a7e1cbb38ea6a630f144c   5169619
# 6   gpcw20250630.zip  9c5262d3b8e48a80480887e5f3035be0   5608677
# 7   gpcw20250331.zip  c861f9d27cf3a0ae1fd4aa4cad3bd49b   4983706
# 8   gpcw20241231.zip  51e2479df7e684165d716185a556e715   5666575
# 9   gpcw20240930.zip  8e84a5390707c2bbabb12ca7052a6892   5221400
# 10  gpcw20240630.zip  3daf56e349e348d012cb91cb2eeb8264   5549341
# 11  gpcw20240331.zip  ab382821d4cc9ddddb72a1b9fea1e29e   4878333
# 12  gpcw20231231.zip  0eb4cdb4053f3361cb1da9d4296c3f55   5646664
# ...

# %%
from sqlalchemy import create_engine
conn = create_engine('postgresql+psycopg2://sa:11111111@10.3.18.56/tdxFS')

# %%
pd.read_sql('000001', conn)

# %%
pd.read_sql('gpcw20240930',conn)

# %%
ls = ['gpcw20250630.zip','gpcw20250331.zip','gpcw20241231.zip']
datacrawler = HistoryFinancialCrawler()
pd.set_option('display.max_columns', None)

# %%
result = datacrawler.fetch_and_parse(reporthook=demo_reporthook, filename=ls[2], path_to_download="/tmp/tmpfile.zip")
dd12 = datacrawler.to_df(data=result)

# %%
result = datacrawler.fetch_and_parse(reporthook=demo_reporthook, filename=ls[0], path_to_download="/tmp/tmpfile.zip")
dd6 = datacrawler.to_df(data=result)

# %%
dd6[dd6.columns[:582]]

# %%
dd6.columns[:582]

# %%
result = datacrawler.fetch_and_parse(reporthook=demo_reporthook, filename=ls[1], path_to_download="/tmp/tmpfile.zip")
dd3 = datacrawler.to_df(data=result)

# %%
dd['report_date']= dd['report_date'].astype(object)
upday = dd['report_date'].iloc[0]
dd = dd.round(2)

# %%
lls = dd.index.values.tolist()

# %%
lls[0]

# %%
pd.DataFrame(dd.iloc[0]).T.reset_index(drop=True).set_index('report_date').to_sql(lls[0], conn, if_exists='append')

# %%
pd.read_sql(lls[10], conn)['report_date'].tail(1).tolist()[0]

# %%
pd.DataFrame(dd.iloc[0]).T.reset_index(drop=True)

# %%
result = datacrawler.fetch_and_parse(reporthook=demo_reporthook, filename=ls[0], path_to_download="/tmp/tmpfile.zip")
dd = datacrawler.to_df(data=result)

# %%
dd['report_date']= dd['report_date'].astype(object)
dd = dd.round(2)

# %%
dd

# %%
dd

# %%
from sqlalchemy import create_engine
conn = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/tdxFS')

# %%
raw = pd.read_sql('000001', conn)

# %%
raw['report_date'].tail(1).tolist()[0] == 20250331

# %%
raw.drop(raw.tail(1).index).set_index('report_date')

# %%
raw

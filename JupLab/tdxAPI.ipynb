# %%
from pytdx.hq import TdxHq_API
from pytdx.exhq import TdxExHq_API
import pandas as pd

eapi =  TdxExHq_API()
api = TdxHq_API()

# %% [markdown]
# ### 深圳（0）上海（1）中证（62）国证（102）

# %%
api.connect('180.153.18.170', 7709)

# %%
api.to_df(api.get_index_bars(9, 1, '000012', 0, 800)).to_sql('000012',engI, if_exists='replace', index=False)
# Out:
# -1

# %%
eapi.connect('47.112.95.207', 7720)

# %%
api.to_df(eapi.get_instrument_bars(9, 62, 'H30067', 1, 5))
# Out:
#           open         high          low        close    position  trade  \
# 0  5770.418457  5863.542480  5749.467773  5862.160645  1185087877      0
# 1  5858.958496  5872.655762  5626.183594  5666.330078  1184762468      8
# 2  5650.266113  5717.351074  5513.458008  5707.069824  1184130973      7
# 3  5692.554688  5699.656250  5584.046387  5626.824707  1183144821      7
# 4  5601.525391  5617.626465  5446.108398  5452.953613  1183221271      8
#
#    price  year  month  day  hour  minute          datetime        amount
# 0    0.0  2026      1   23    15       0  2026-01-23 15:00  20864.759766
# 1    0.0  2026      1   26    15       0  2026-01-26 15:00  20229.195312
# 2    0.0  2026      1   27    15       0  2026-01-27 15:00  18995.806641
# 3    0.0  2026      1   28    15       0  2026-01-28 15:00  17069.728516
# 4    0.0  2026      1   29    15       0  2026-01-29 15:00  17219.044922

# %% [markdown]
# ### 获取k线
# * category
# ```
#  K线种类
# 0 5分钟K线 1 15分钟K线 2 30分钟K线 3 1小时K线 4 日K线
# 5 周K线
# 6 月K线
# 7 1分钟
# 8 1分钟K线 9 日K线
# 10 季K线
# 11 年K线
# ```
# * market -> 市场代码 0:深圳，1:上海
# * stockcode -> 证券代码;
# * start -> 指定的范围开始位置;
# * count -> 用户要请求的 K 线数目，最大值为 800

# %%
api.to_df(api.get_security_bars(8, 0, '000001', 800, 800))

# %%
api.to_df(api.get_index_bars(9, 0, 'H11006', 1, 21))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
eapi.connect('47.112.95.207', 7720)

# %%
eapi.to_df(eapi.get_instrument_bars(9, 62, 'H11006', 0, 10))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# 1分钟K线(8)1D240 2D480 3D720 bar, 5分钟K线(0)1D48 5D240 8D384 13D624 bar ,  日K线(9)
# 每次800   0SZ  1SH  ======= 在线分析

# %%
from pytdx.hq import TdxHq_API
import pandas as pd
import plotly.express as px

import numpy as np 

api = TdxHq_API()

# %%
api.connect('121.36.81.195', 7709)

# %%
stockCodeSel = '002469'

# %%
if stockCodeSel < '600000':
    m = 0
else:
    m = 1

# %%
df3 = api.to_df(api.get_security_bars(8, m, stockCodeSel, 0, 720))
df5 = api.to_df(api.get_security_bars(0, m, stockCodeSel, 0, 240))
df13 = api.to_df(api.get_security_bars(0, m, stockCodeSel, 0, 624))
df21 = api.to_df(api.get_security_bars(9, m, stockCodeSel, 0, 21))
df55 = api.to_df(api.get_security_bars(9, m, stockCodeSel, 0, 55))
df144 = api.to_df(api.get_security_bars(9, m, stockCodeSel, 0, 144))

# %%
df3

# %%
df750 = api.to_df(api.get_index_bars(9, 1, '000001', 10, 799))

# %%
api.to_df(api.get_index_bars(9, 1, '000510', 10, 799))

# %% [markdown]
# ====== 数据说明df3三天1分钟k线数据, df5五天5分钟k线数据,df13十三天五分钟k线数据, 其他日k线数据

# %% [markdown]
# 个股

# %%
df3 = api.to_df(api.get_security_bars(8, 0, '000001', 0, 720))
df5 = api.to_df(api.get_security_bars(0, 0, '000001', 0, 240))
df13 = api.to_df(api.get_security_bars(0, 0, '000001', 0, 624))
df21 = api.to_df(api.get_security_bars(9, 0, '000001', 0, 21))
df55 = api.to_df(api.get_security_bars(9, 0, '000001', 0, 55))
df144 = api.to_df(api.get_security_bars(9, 0, '000001', 0, 144))

# %% [markdown]
# 指数

# %%
df3 = api.to_df(api.get_index_bars(8, 1, '000001', 0, 720))
df5 = api.to_df(api.get_index_bars(0, 1, '000001', 0, 240))
df13 = api.to_df(api.get_index_bars(0, 1, '000001', 0, 624))
df21 = api.to_df(api.get_index_bars(9, 1, '000001', 0, 21))
df55 = api.to_df(api.get_index_bars(9, 1, '000001', 0, 55))
df144 = api.to_df(api.get_index_bars(9, 1, '000001', 0, 144))

# %%
lsDF = [df3,df5,df13,df21,df55,df144]
lsD = ['3D','5D',"13D","21D","55D","144D"]
con = [720,240,624,21,55,144]

# %% [markdown]
# 价格 加 数量 权 (扩展数量加权：权重)

# %%
def norm(df, column_name,n):
    min_val = df[column_name].min()
    max_val = df[column_name].max()
    normalized_column = (df[column_name] - min_val) / (max_val - min_val)
    scaled_column = normalized_column * (n - 1) + 1
    discrete_scaled_column = scaled_column.round().astype(int)
    return discrete_scaled_column

# %%
plDF = pd.DataFrame()
for n, df in enumerate(lsDF):
    weights = norm(df,'vol',con[n])
    weighted_data = np.repeat(df['close'], repeats=weights)
    dDF = pd.DataFrame(weighted_data)
    dDF['周期'] = lsD[n]
    plDF = pd.concat([plDF,dDF])

# %%
plDF

# %%
fig = px.violin(plDF,y='close',facet_col='周期',facet_col_spacing=0.01,box=True,violinmode='overlay',title='价格加权')
fig.show()

# %%
fig = px.box(plDF,y='close',facet_col='周期',facet_col_spacing=0.03,boxmode='group',title='价格加权')
fig.show()

# %% [markdown]
# 价格

# %%
plDF = pd.DataFrame()
for n, df in enumerate(lsDF):
    # weights = norm(df,'amount',con[n])
    # weighted_data = np.repeat(df['close'], repeats=weights)
    dDF = pd.DataFrame(df['close'])
    dDF['周期'] = lsD[n]
    plDF = pd.concat([plDF,dDF])

# %%
fig = px.violin(plDF,y='close',facet_col='周期',facet_col_spacing=0.03,box=True,violinmode='overlay',title='价格')
fig.show()

# %%
fig = px.box(plDF,y='close',facet_col='周期',facet_col_spacing=0.03,boxmode='group',title='价格')
fig.show()

# %% [markdown]
# 数量

# %%
plDF = pd.DataFrame()
for n, df in enumerate(lsDF):
    dDF = pd.DataFrame(df['amount'])
    dDF['周期'] = lsD[n]
    plDF = pd.concat([plDF,dDF])

# %%
fig = px.violin(plDF[plDF['周期'].isin(['21D','55D','144D'])],y='amount',facet_col='周期',facet_col_spacing=0.03,box=True,violinmode='overlay',title='数量')
fig.show()

# %%
fig = px.violin(plDF,y='amount',facet_col='周期',facet_col_spacing=0.03,box=True,violinmode='overlay',title='数量')
fig.show()

# %%
fig = px.box(plDF,y='amount',facet_col='周期',facet_col_spacing=0.03,boxmode='group',title='数量')
fig.show()

# %%
df144

# %%
fig = px.violin(df3,y='vol',x='minute',box=True,violinmode='group',title='数量')
fig.show()

# %%
fig = px.box(df3,y='vol',x='minute',boxmode='group',title='数量')
fig.show()

# %% [markdown]
# ========== 三日分钟交易量密度图

# %%
fig = px.density_contour(df3, y="hour",x='minute',z='amount',histfunc='sum',nbinsx=60,nbinsy=7)
fig.update_traces(contours_coloring="fill", contours_showlabels = True)

fig.show()

# %%
fig = px.density_contour(df3, y="day",x='hour',z='amount',nbinsx=4,nbinsy=3, histfunc='sum')

fig.update_traces(contours_coloring="fill", contours_showlabels = True)
fig.show()

# %%
fig = px.density_contour(df3, y="day",x='minute',z='amount',nbinsx=60,nbinsy=3, histfunc='sum')

fig.update_traces(contours_coloring="fill", contours_showlabels = True)
fig.show()

# %% [markdown]
# 分钟交易额统计

# %%
api.connect('121.36.81.195', 7709)

# %%
dff = api.to_df(api.get_security_bars(8, 1, '600889', 0, 799))

# %%
fig = px.density_heatmap(dff, x='minute',y='hour',z='amount',histfunc='sum',histnorm='percent' ,nbinsx=60,nbinsy=7,text_auto='.2r')
fig.show()

# %%
dff = api.to_df(api.get_security_bars(0, 0, '000002', 0, 799))
fig = px.density_heatmap(dff, x='minute',y='hour',z='amount',histfunc='sum',histnorm='percent' ,nbinsx=12,nbinsy=7,text_auto='.2r')
fig.show()

# %% [markdown]
# 小时交易额统计

# %%
api.connect('121.36.81.195', 7709)

# %%
api.to_df(api.get_security_bars(0, 1, '600489', 0, 799))

# %%
dff = api.to_df(api.get_security_bars(0, 1, '600489', 0, 799))
fig = px.density_heatmap(dff, x='hour',y='day',z='amount',histfunc='sum',histnorm='percent' ,nbinsx=7,nbinsy=31,text_auto='.2r')
fig.show()

# %% [markdown]
# 日交易额统计

# %%
dff = api.to_df(api.get_security_bars(9, 0, '000001', 0, 799))

# %%
fig = px.density_heatmap(dff, x='day',y='month',z='amount',histfunc='sum',histnorm='percent' ,nbinsx=31,nbinsy=12,text_auto='.2r')
fig.show()

# %%
fig = px.density_contour(df3, y="day",x='minute',z='vol',nbinsx=60,nbinsy=3, histfunc='sum')
# fig = px.density_contour(df3, y="hour",x='minute',z='vol',nbinsx=60,nbinsy=4, histfunc='sum')
# fig.update_traces(contours_coloring="fill", contours_showlabels = True)
fig.show()

# %% [markdown]
# ==== 参数 --histfunc: 'count', 'sum', 'avg', 'min', or 'max'   --histnorm: 'percent', 'probability', 'density', or 'probability density'

# %%
import pandas as pd
import plotly.express as px
from sqlalchemy import create_engine
# eng = create_engine('postgresql+psycopg2://sa:11111111@10.3.18.56/tdxIndex')
engI = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/tdxIndex')

# %%
idxDF = pd.read_sql('000001', eng)

# %%
# ,marginal_x="histogram", marginal_y="histogram"
fig = px.density_heatmap(idxDF[(idxDF['year']>2000) & (idxDF['year']<2025) ], x='day',y='month',z='amount',histfunc='min',histnorm='percent',nbinsx=35,nbinsy=12,text_auto='.2r')
fig.show()

# %%
fig = px.density_heatmap(idxDF, x='month',y='year',z='amount',histfunc='avg',histnorm='percent',nbinsx=12,nbinsy=50,text_auto='.2f')
fig.show()

# %%
fig = px.density_heatmap(df13, x='minute',y='hour',z='amount',histfunc='max',histnorm='percent' ,nbinsx=60,nbinsy=8,text_auto='.2')
fig.show()

# %%
opIndex= pd.read_sql('optIndexs',eng)
indexCode = '880682'
indexName = opIndex[opIndex['IndexCode']==indexCode]['IndexName'].values[0]

# %%
selDF = pd.read_sql(indexCode, eng)

shDF = pd.read_sql('000001', eng)
szDF = pd.read_sql('399001', eng)
hs300DF = pd.read_sql('000300', eng)
csa500DF = pd.read_sql('000510', eng)
cs500DF = pd.read_sql('000905', eng)
sh50DF = pd.read_sql('000016', eng)
kc50DF = pd.read_sql('000688', eng)
cs1000DF = pd.read_sql('000852', eng)

# %%
plData = pd.DataFrame()

# %%
plData['datetime'] = shDF.tail(1150)['datetime'].reset_index(drop=True)

# %%
# plData = pd.merge(plData,selDF.tail(1150)[['datetime','close']].rename(columns={'close':indexName}),on='datetime',how='outer')

# %%
plData = pd.merge(plData,selDF.tail(1150)[['datetime','close']].rename(columns={'close':indexName}),on='datetime',how='outer')
plData = pd.merge(plData,shDF.tail(1150)[['datetime','close']].rename(columns={'close':'上证指数'}),on='datetime',how='outer')
plData = pd.merge(plData,szDF.tail(1150)[['datetime','close']].rename(columns={'close':'深证成指'}),on='datetime',how='outer')
plData = pd.merge(plData,hs300DF.tail(1150)[['datetime','close']].rename(columns={'close':'沪深300'}),on='datetime',how='outer')
plData = pd.merge(plData,csa500DF.tail(1150)[['datetime','close']].rename(columns={'close':'中证A500'}),on='datetime',how='outer')
plData = pd.merge(plData,cs500DF.tail(1150)[['datetime','close']].rename(columns={'close':'中证500'}),on='datetime',how='outer')
plData = pd.merge(plData,sh50DF.tail(1150)[['datetime','close']].rename(columns={'close':'上证50'}),on='datetime',how='outer')
plData = pd.merge(plData,kc50DF.tail(1150)[['datetime','close']].rename(columns={'close':'科创50'}),on='datetime',how='outer')
plData = pd.merge(plData,cs1000DF.tail(1150)[['datetime','close']].rename(columns={'close':'中证1000'}),on='datetime',how='outer')

# %%
plData

# %%
plData[indexName] = selDF.tail(1150)['close'].reset_index(drop=True).set_index('datetime')
plData['上证指数'] = szDF.tail(1150)['close'].reset_index(drop=True).set_index('datetime')
plData['深证成指'] = szDF.tail(1150)['close'].reset_index(drop=True).set_index('datetime')
plData['沪深300'] = hs300DF.tail(1150)['close'].reset_index(drop=True).set_index('datetime')
plData['中证A500'] = csa500DF.tail(1150)['close'].reset_index(drop=True).set_index('datetime')
plData['中证500'] = cs500DF.tail(1150)['close'].reset_index(drop=True).set_index('datetime')
plData['上证50'] = sh50DF.tail(1150)['close'].reset_index(drop=True).set_index('datetime')
plData['科创50'] = kc50DF.tail(1150)['close'].reset_index(drop=True).set_index('datetime')
plData['中证1000'] = cs1000DF.tail(1150)['close'].reset_index(drop=True).set_index('datetime')

# %%
plData

# %%
def normalize(x):
    return (x - x.min()) / (x.max() - x.min())

# %%
ddd = plData.set_index('datetime').apply(normalize, axis=0)

# %%
fig = px.line(ddd.reset_index(),x='datetime', y=plData.columns,line_shape='linear')
# fig = px.area(ddd.reset_index(),x='datetime', y=plData.columns)

fig.update_xaxes(showspikes=True, spikecolor="black", spikesnap="cursor", spikemode="across",spikethickness=0.6)
fig.update_yaxes(showspikes=True, spikecolor="black", spikesnap="cursor", spikemode="across",spikethickness=0.6)
fig.update_traces(hovertemplate='%{y:.2f}')
fig.update_layout(hovermode='x')
fig.show(config={'scrollZoom': True,'displaylogo':False})

# %% [markdown]
# ## fs原始数据初始化

# %%
import pandas as pd
from sqlalchemy import create_engine
from pytdx.hq import TdxHq_API
from pytdx.crawler.base_crawler import demo_reporthook
from pytdx.crawler.history_financial_crawler import HistoryFinancialCrawler
from tqdm import tqdm

# %%
engF = create_engine('postgresql+psycopg2://sa:11111111@10.3.18.56/tdxFS')

# %%
datacrawler = HistoryFinancialCrawler()
api = TdxHq_API()
api.connect('180.153.18.170', 7709)

# %%
ls = ['20200331','20200630','20200930','20201231','20210331','20210630','20210930','20211231','20220331','20220630','20220930','20221231','20230331','20230630','20230930','20231231','20240331','20240630','20240930','20241231','20250331','20250630']

# %%
ls = ['20221231','20230331','20230630','20230930','20231231','20240331','20240630','20240930','20241231','20250331','20250630']

# %%
l= "20251231"
result = datacrawler.fetch_and_parse(reporthook=demo_reporthook, filename='gpcw'+l+'.zip', path_to_download="/tmp/tmpfile.zip")
# Out:
# Downloaded 164, Total is 0

# %%
datacrawler.to_df(data=result)

# %%
for l in tqdm(ls):
    i = 'gpcw'+l+'.zip'
    result = datacrawler.fetch_and_parse(reporthook=demo_reporthook, filename=i, path_to_download="/tmp/tmpfile.zip")
    dd = datacrawler.to_df(data=result)
    dd = dd[dd.columns[:582]]
    dd['report_date']= dd['report_date'].astype(object)
    upday = dd['report_date'].iloc[0]
    dd = dd.round(4)
    dd.to_sql(i[:12],engF, if_exists='replace')

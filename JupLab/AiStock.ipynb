# %%
from sqlalchemy import create_engine
import pandas as pd
import plotly.express as px

# %%
engI = create_engine('postgresql+psycopg://sa:11111111@111.61.77.88:65123/tdxIndex')
engB = create_engine('postgresql+psycopg://sa:11111111@111.61.77.88:65123/StockBas')
engS = create_engine('postgresql+psycopg://sa:11111111@111.61.77.88:65123/tdxStocks')

# %%
import tqdm
for i in tqdm.tqdm(range(10000)):
    i = i+1
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 3186918.93it/s]

# %%
consdf = pd.read_sql('IndexCons', engI)

# %%
consdf[consdf['StockCode'].isin(['600256'])]
# Out:
#        IndexCode IndexName StockCode StockName IndexSTL          DP
# 81        880202      新疆板块    600256      广汇能源       地区  2025-09-05
# 5569      880310        石油    600256      广汇能源       行业  2025-09-05
# 12670     880519       碳中和    600256      广汇能源       概念  2025-09-05
# 14242     880526      高分红股    600256      广汇能源       风格  2025-09-05
# 18029     880544        光伏    600256      广汇能源       概念  2025-09-05
# ...          ...       ...       ...       ...      ...         ...
# 169914    H30362     基本300    600256      广汇能源       策略  2019-06-17
# 174954    931248      油气资源    600256      广汇能源       主题  2023-06-12
# 177138    H11031    AMAC采矿    600256      广汇能源       行业  2015-06-11
# 177265    H50019      上红回报    600256      广汇能源       策略  2024-12-16
# 179458    932077    全指能源行业    600256      广汇能源       行业  2023-03-13
#
# [70 rows x 6 columns]

# %%
df[df['StockCode'] == '600256']

# %%
px.pie(df[df['StockCode'] == '600256'])

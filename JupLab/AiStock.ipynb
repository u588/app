# %%
from sqlalchemy import create_engine
import pandas as pd
import plotly.express as px

# %%
engI = create_engine('postgresql+psycopg://sa:11111111@111.61.77.88:65123/tdxIndex')
engB = create_engine('postgresql+psycopg://sa:11111111@111.61.77.88:65123/StockBas')
engS = create_engine('postgresql+psycopg://sa:11111111@111.61.77.88:65123/tdxStocks')

# %%
import tqdm
for i in tqdm.tqdm(range(10000)):
    i = i+1
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 3186918.93it/s]

# %%
consdf = pd.read_sql('IndexCons', engI)

# %%
consdf[consdf['IndexCode'].isin(['881241'])]
# Out:
#       IndexCode IndexName StockCode StockName IndexSTL          DP
# 69802    881241      医疗器械    002223      鱼跃医疗       行业  2025-09-08
# 69803    881241      医疗器械    002382      蓝帆医疗       行业  2025-09-08
# 69804    881241      医疗器械    002432      九安医疗       行业  2025-09-08
# 69805    881241      医疗器械    002901      大博医疗       行业  2025-09-08
# 69806    881241      医疗器械    002950      奥美医疗       行业  2025-09-08
# ...         ...       ...       ...       ...      ...         ...
# 69894    881241      医疗器械    688677      海泰新光       行业  2025-09-08
# 69895    881241      医疗器械    832278      鹿得医疗       行业  2025-09-08
# 69896    881241      医疗器械    835892      中科美菱       行业  2025-09-08
# 69897    881241      医疗器械    836504      博迅生物       行业  2025-09-08
# 69898    881241      医疗器械    872925      锦好医疗       行业  2025-09-08
#
# [97 rows x 6 columns]

# %%
df[df['StockCode'] == '600256']

# %%
px.pie(df[df['StockCode'] == '600256'])

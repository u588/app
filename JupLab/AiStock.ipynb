# %%
from sqlalchemy import create_engine
import pandas as pd
import plotly.express as px

# %%
engI = create_engine('postgresql+psycopg://sa:11111111@111.61.77.88:65123/tdxIndex')
engB = create_engine('postgresql+psycopg://sa:11111111@111.61.77.88:65123/StockBas')
engS = create_engine('postgresql+psycopg://sa:11111111@111.61.77.88:65123/tdxStocks')

# %%
consdf = pd.read_sql('IndexCons', engI)

# %%
consdf[consdf['StockCode'].isin(['600256'])]
# Out:
#        IndexCode   IndexName StockCode StockName IndexSTL          DP
# 80        880202        新疆板块    600256      广汇能源       地区  2025-08-30
# 5567      880310          石油    600256      广汇能源       行业  2025-08-30
# 12661     880519         碳中和    600256      广汇能源       概念  2025-08-30
# 14204     880526        高分红股    600256      广汇能源       风格  2025-08-30
# 17960     880544          光伏    600256      广汇能源       概念  2025-08-30
# ...          ...         ...       ...       ...      ...         ...
# 162944    932022  中证红利(全)SGD    600256      广汇能源       指数  2025-02-14
# 164642    H11031      AMAC采矿    600256      广汇能源       指数  2015-06-11
# 170599    H50015         沪西部    600256      广汇能源       指数  2019-06-17
# 172111    932077      全指能源行业    600256      广汇能源       指数  2023-03-13
# 176114    H30455      沪港深500    600256      广汇能源       指数  2024-06-17
#
# [72 rows x 6 columns]
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
df[df['StockCode'] == '600256']

# %%
px.pie(df[df['StockCode'] == '600256'])

# %% [markdown]
# datasetsforecast 通常与另一个名为 statsforecast 的库协同工作。statsforecast 提供了模型定义、训练和预测的核心功能，而 datasetsforecast 则提供数据。

# %%
# 1. 导入必要的库 
from datasetsforecast.m3 import M3 # 导入M3数据集 
from statsforecast import StatsForecast # 核心预测类 
from statsforecast.models  import AutoARIMA, TSB, AutoETS # 导入模型 
from statsforecast.utils  import ConformalIntervals # 用于预测区间

# %%
df, *_ = M3.load('data',  group='Monthly')
# Out:
# 100%|██████████| 1.76M/1.76M [00:01<00:00, 1.13MiB/s]
# INFO:datasetsforecast.utils:Successfully downloaded M3C.xls, 1757696, bytes.
# /home/ts/.local/lib/python3.12/site-packages/datasetsforecast/m3.py:108: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   freq = pd.tseries.frequencies.to_offset(class_group.freq)

# %%
df.tail(10)
# Out:
#        unique_id         ds       y
# 167552      M999 1993-05-31  5296.5
# 167553      M999 1993-06-30  5305.5
# 167554      M999 1993-07-31  5264.7
# 167555      M999 1993-08-31  5259.4
# 167556      M999 1993-09-30  5248.9
# 167557      M999 1993-10-31  5225.9
# 167558      M999 1993-11-30  5236.3
# 167559      M999 1993-12-31  5186.6
# 167560      M999 1994-01-31  5143.4
# 167561      M999 1994-02-28  5152.6

# %%
 
# 3. 定义你想要比较的模型列表 
models = [
    AutoARIMA(), # 自动ARIMA 
    AutoETS(),       # 指数平滑 
    # NHITS(h=12, input_size=24, # NHITS深度学习模型 
    #       loss='mae', max_steps=50)
]

# %%
# 4. 初始化 StatsForecast 对象 
#    它负责处理数据和模型训练 
sf = StatsForecast(
    # df=df,
    models=models,
    freq='M', # 数据频率为 Monthly 
    n_jobs=-1 # 使用所有CPU核心并行计算 
)

# %%
# 5. 进行预测 
#    h=12 表示预测未来12个时间点 
forecasts = sf.forecast(df=df,h=12,  level=[90]) # level 为置信区间
# Out:
# /home/ts/.local/lib/python3.12/site-packages/utilsforecast/processing.py:378: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   freq = pd.tseries.frequencies.to_offset(freq)
# /home/ts/.local/lib/python3.12/site-packages/utilsforecast/processing.py:434: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   freq = pd.tseries.frequencies.to_offset(freq)

# %%
from mootdx.quotes import Quotes
import pandas as pd
import re
from sqlalchemy import create_engine

eng = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/StockBas')
engs = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/tdxStocks')

# %%
# def getFcast(StockCode, StockName):

qf10='研报评级'
client = Quotes.factory(market='std')

# %%
client.F10('000001', qf10)
# Out:
# '研报评级☆ ◇000001 平安银行 更新日期：2025-09-02◇ 通达信沪深京F10\r\n★本栏包括【1.投资评级统计】【2.盈利预测统计】【3.盈利预测明细】【4.研报摘要】\r\n          【5.机构调研】\r\n\r\n【1.投资评级统计】最新评级日期:2025-08-27\r\n时间段   买入评级次数   增持评级次数   中性评级次数   减持评级次数   卖出评级次数   评级次数合计\r\n────────────────────────────────────────────────\r\n1周内               1              0              0              0              0              1\r\n1月内               4              3              0              0              0              7\r\n2月内               4              3              0              0              0              7\r\n3月内               4              3              0              0              0              7\r\n6月内              20             16              1              0              0             37\r\n1年内              20             16              1              0              0             37\r\n────────────────────────────────────────────────\r\n\r\n【2.盈利预测统计】(近6个月)\r\n┌──────────┬─────┬─────┬─────┬─────┬─────┬─────┐\r\n│财务指标            │    2022年│    2023年│    2024年│2025年预测│2026年预测│2027年预测│\r\n├──────────┼─────┼─────┼─────┼─────┼─────┼─────┤\r\n│每股收益(元)        │      2.35│      2.39│      2.29│      2.23│      2.28│      2.37│\r\n│每股净资产(元)      │     18.80│     20.74│     21.89│     23.87│     25.80│     27.90│\r\n│净资产收益率%       │     10.47│      9.84│      8.99│      9.52│      9.02│      8.68│\r\n│归母净利润(百万元)  │  45516.00│  46455.00│  44508.00│  44456.89│  45485.75│  47281.54│\r\n│营业收入(百万元)    │ 179895.00│ 164699.00│ 146695.00│ 139134.03│ 141418.91│ 146025.39│\r\n│营业利润(百万元)    │  57475.00│  57928.00│  55206.00│  53856.13│  54219.75│  55516.88│\r\n└──────────┴─────┴─────┴─────┴─────┴─────┴─────┘\r\n\r\n【3.盈利预测明细】(近6个月)\r\n日期           评级       评级变化       目标价    2025EPS    2026EPS    2027EPS       研究机构\r\n────────────────────────────────────────────────\r\n2025-08-27     买入       维持              ---       2.22       2.24       2.32       东兴证券\r\n2025-08-24     买入       维持             14.7       2.07       2.08       2.15       中信建投\r\n2025-08-23     买入       维持            14.33       2.28       2.32       2.37       华泰证券\r\n2025-08-23     增持       维持              ---       2.17       2.20       2.27       招商证券\r\n2025-08-23     增持       维持              ---       2.24       2.26       2.30       光大证券\r\n2025-08-23     增持       维持            13.64        ---        ---        ---       中金公司\r\n2025-08-22     买入       维持               14       2.14       2.21       2.33       浙商证券\r\n2025-04-22     增持       维持              ---       2.26       2.34       2.43       中泰证券\r\n2025-04-22     增持       首次              ---       2.31       2.43       2.59       国海证券\r\n2025-04-21     增持       维持            12.39       2.31       2.38       2.46       天风证券\r\n2025-04-20     买入       维持              ---       2.13       2.14       2.21       申万宏源\r\n2025-04-20     买入       维持              ---       2.34       2.45       2.64       华福证券\r\n2025-04-20     买入       维持            13.81       2.31       2.40       2.56       国投证券\r\n2025-04-20     增持       维持            13.28        ---        ---        ---       中金公司\r\n2025-04-20     买入       维持            14.34       2.11       2.14       2.20       中信建投\r\n2025-04-20     增持       维持            12.96       2.26       2.29       2.42       华创证券\r\n2025-04-19     买入       维持            13.64       2.11       2.16       2.28       浙商证券\r\n2025-04-19     买入       维持              ---       2.25       2.26       2.30       国盛证券\r\n2025-04-18     买入       维持            13.98       2.30       2.33       2.38       华泰证券\r\n2025-04-18     增持       维持              ---       2.15       2.17       2.21       招商证券\r\n2025-03-19     增持       维持              ---       2.29       2.35       2.43       财通证券\r\n2025-03-19     增持       调低            12.76       2.43       2.52       2.60       天风证券\r\n2025-03-18     增持       维持              ---       2.36       2.38       2.53       万联证券\r\n2025-03-18     买入       维持              ---       2.27       2.32       ...

# %%
StockCode = StockList.iloc[n,0]
StockName = StockList.iloc[n,1]

# %%
StockCode = '000001'
StockName = '平安银行'

# %%
txtRaw = client.F10(StockCode, qf10)[116:]

# %%
txtRaw = client.F10(StockCode, qf10)[116:]

txt = txtRaw.replace('│',' ')                
txt = re.sub('([\u2500-\u25f7])','',txt)

ftxt = txt[txt.find('【2.盈利预测统计】'):]
etxt = ftxt[:ftxt.find('【3.盈利预测明细】')]
dd = etxt.splitlines(keepends=False)

Data = pd.DataFrame(columns=())
i = 0
while i < len(dd):
    lis = dd[i].split()
    if len(lis)!=7:
        pass
    else:
        df = pd.DataFrame(lis).T
        Data = pd.concat([Data, df],axis=0)
    i=i+1
Data.reset_index(drop=True,inplace=True)
Data = Data.replace('---',pd.NA)

Data.columns=list(Data.loc[0])
Data['StockCode'] = StockCode
Data['StockName'] = StockName

# Data[['StockCode','StockName', '财务指标', '2021年', '2022年', '2023年', '2024年预测', '2025年预测','2026年预测' ]].tail(-1).set_index('StockCode')

# %%
cols = Data.columns.to_list()

# %%
Data[cols[-2:]+cols[:-2]]
# Out:
#   StockCode StockName        财务指标      2022年      2023年      2024年    2025年预测  \
# 0    000001      平安银行        财务指标      2022年      2023年      2024年    2025年预测
# 1    000001      平安银行     每股收益(元)       2.35       2.39       2.29       2.23
# 2    000001      平安银行    每股净资产(元)      18.80      20.74      21.89      23.87
# 3    000001      平安银行     净资产收益率%      10.47       9.84       8.99       9.52
# 4    000001      平安银行  归母净利润(百万元)   45516.00   46455.00   44508.00   44456.89
# 5    000001      平安银行   营业收入(百万元)  179895.00  164699.00  146695.00  139134.03
# 6    000001      平安银行   营业利润(百万元)   57475.00   57928.00   55206.00   53856.13
#
#      2026年预测    2027年预测
# 0    2026年预测    2027年预测
# 1       2.28       2.37
# 2      25.80      27.90
# 3       9.02       8.68
# 4   45485.75   47281.54
# 5  141418.91  146025.39
# 6   54219.75   55516.88

# %%
pd.concat([Data.columns.values[-2:],Data.columns.values[:-2]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pd.concat([Data.columns.values[-2:],Data.columns.values[:-2]])
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/reshape/concat.py:448, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
# --> 448 ndims = self._get_ndims(objs)
#     449 sample, objs = self._get_sample_object(objs, ndims, keys, names, levels)
#     451 # Standardize axis parameter to int
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/reshape/concat.py:489, in _Concatenator._get_ndims(self, objs)
#     484     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     485         msg = (
#     486             f"cannot concatenate object of type '{type(obj)}'; "
#     487             "only Series and DataFrame objs are valid"
#     488         )
# --> 489         raise TypeError(msg)
#     491     ndims.add(obj.ndim)
#     492 return ndims
#
# TypeError: cannot concatenate object of type '<class 'numpy.ndarray'>'; only Series and DataFrame objs are valid

# %%
StockList = pd.read_sql('StocksList', engs)[['code','name']]

# %%
StockList

# %%
n = 0

# %%
getFcast(StockList.iloc[n,0], StockList.iloc[n,1])

# %%
import pandas as pd
from pytdx.hq import TdxHq_API
from pytdx.crawler.history_financial_crawler import HistoryFinancialListCrawler

# %%
api = TdxHq_API()
api.connect('180.153.18.170', 7709)

# %%
crawler = HistoryFinancialListCrawler()
list_data = crawler.fetch_and_parse()
print(pd.DataFrame(data=list_data))
# Out:
#              filename                              hash  filesize
# 0    gpcw20250930.zip  1f43e000d0fd371127b8a68a3246308c       164
# 1    gpcw20250331.zip  3789fb1318820e503ea43e333de614d4       165
# 2    gpcw20241231.zip  e404e326dfa322d10a5e2f3afab5137f      2244
# 3    gpcw20240930.zip  3ec5cb4122982b0ca1e34175494ad6f6   5054601
# 4    gpcw20240630.zip  ecccb56be47cbfd08aa1779ec3c56316   5423825
# ..                ...                               ...       ...
# 137  gpcw19910331.zip  1792cb5b47b6a1ae01794d3972b0adbf       165
# 138  gpcw19901231.zip  b5ebcd86468752d564603a72701ba736     12658
# 139  gpcw19900630.zip  6bb4c75c61c7066d3a03b3e24008b33f       165
# 140  gpcw19891231.zip  b0ad534ba255a73fe9368b8a0d5551c6       333
# 141  gpcw19881231.zip  4fcec5f4cf87d4f97d7f39adbf58145d       164
#
# [142 rows x 3 columns]

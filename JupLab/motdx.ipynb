# %%
import pandas as pd
from pytdx.hq import TdxHq_API
from pytdx.crawler.history_financial_crawler import HistoryFinancialListCrawler

# %%
api = TdxHq_API()
api.connect('180.153.18.170', 7709)

# %%
crawler = HistoryFinancialListCrawler()
list_data = crawler.fetch_and_parse()
print(pd.DataFrame(data=list_data))
# Out:
#              filename                              hash  filesize
# 0    gpcw20250930.zip  1f43e000d0fd371127b8a68a3246308c       164
# 1    gpcw20241231.zip  104c22b147e2c6218524c9668550f428       165
# 2    gpcw20240930.zip  7bea4a1e1b073134df6ad0697f894c5e   5001231
# 3    gpcw20240630.zip  d2ad176161ebbc0cea95a46ddc316432   5417150
# 4    gpcw20240331.zip  32b46d83fafb9bf34cdaa6a2ee6098ef   4804152
# ..                ...                               ...       ...
# 136  gpcw19910331.zip  1792cb5b47b6a1ae01794d3972b0adbf       165
# 137  gpcw19901231.zip  04f2f7f299130200a9a2cf0057b65c44     12634
# 138  gpcw19900630.zip  6bb4c75c61c7066d3a03b3e24008b33f       165
# 139  gpcw19891231.zip  b0ad534ba255a73fe9368b8a0d5551c6       333
# 140  gpcw19881231.zip  4fcec5f4cf87d4f97d7f39adbf58145d       164
#
# [141 rows x 3 columns]

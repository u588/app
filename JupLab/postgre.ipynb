# %%
import pandas as pd
from sqlalchemy import create_engine


eng16 = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56:5432/tdxStocks')
eng17 = create_engine('postgresql+psycopg://sa:11111111@10.3.18.59:5433/FindStocks')

# %%
df = pd.read_sql('csIndex2024_discard', eng16)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.sql('csIndex2024_discard', eng16)
#
# AttributeError: module 'pandas' has no attribute 'sql'

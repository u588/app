# %%
# notebooks/confidence_analysis.ipynb
from visualization.confidence_dashboard import ConfidenceDashboard
from dynamic_price_system.core.technical_confidence import TechnicalConfidence

# 初始化
conf_calc = TechnicalConfidence()
dashboard = ConfidenceDashboard()

# 计算单标的置信度
result = conf_calc.calculate(tech_indicators, stock_df)

# 创建并显示面板
fig = dashboard.create_single_stock_dashboard(
    code='600938',
    name='中国海油',
    confidence_result=result,
    indicators=tech_indicators,
    stock_data=stock_df
)
fig.show()

# 导出
dashboard.export_dashboard(fig, "output/600938_confidence.html")

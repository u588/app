# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import plotly.express as px
from tqdm import tqdm

# %%
engS = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/tdxStocks')
engI = create_engine('postgresql+psycopg://sa:11111111@10.3.18.56/tdxIndex')

# %%
StockList = pd.read_sql('akStocksList', engS)[['StockCode','StockName']].values.tolist()

# %%
indexList = pd.read_sql('optIndexs', engI)[['IndexCode','IndexName']].values.tolist()

# %% [markdown]
# 融合指数收益率

# %%
dfI = pd.DataFrame()
for code in tqdm(indexList):
    try:
        df_tmp = pd.read_sql(code[0], engI).set_index('datetime')['close'].to_frame()
        df_tmp['close'] = np.log(df_tmp['close']  / df_tmp['close'].shift(1))        
        df_tmp.rename(columns={'close':code[0]+':'+code[1]}, inplace=True)
        dfI = pd.merge(dfI,df_tmp,right_index=True, left_index=True,how='outer')
    except:
        pass
        print(code+' pass ! ')

# %%
dfII = pd.read_excel('/home/ts/app/AiStock/Linkage/MergIndex.xlsx')

# %%
dfII.set_index('datetime', inplace=True)

# %%
np.log(dfII/dfII.shift(1)).dropan(thresh=100, axis=1)

# %%
dfI = pd.read_excel('/home/ts/app/AiStock/Linkage/ROEIndex.xlsx')

# %%
dfI

# %%
dfI.dropna(axis=0, thresh=100)

# %%
dfI.to_excel('/home/ts/app/AiStock/Linkage/ROEIndex.xlsx')

# %% [markdown]
# 融合所有数据

# %%
dfI = pd.DataFrame()
for code in tqdm(indexList):
    try:
        df_tmp = pd.read_sql(code[0], engI).set_index('datetime')['close'].to_frame()
        df_tmp.rename(columns={'close':code[0]+':'+code[1]}, inplace=True)
        dfI = pd.merge(dfI,df_tmp,right_index=True, left_index=True,how='outer')
    except:
        pass
        print(code+' pass ! ')
# Out:
# 100%|██████████| 1620/1620 [07:46<00:00,  3.47it/s]

# %%
dfI.drop('2025-10-08 15:00').tail(30)
# Out:
#                   000001:上证指数  000009:上证380  000010:上证180  000015:红利指数  \
# datetime
# 2025-09-26 15:00      3828.11       6493.85      9907.151      2969.73
# 2025-09-29 15:00      3862.53       6564.97     10032.070      2960.96
# 2025-09-30 15:00      3882.78       6640.51     10136.840      2952.83
# 2025-10-09 15:00      3933.97       6750.94     10318.849      2971.88
# 2025-10-10 15:00      3897.03       6655.43     10133.160      3005.76
# 2025-10-13 15:00      3889.50       6632.96     10120.640      3006.48
# 2025-10-14 15:00      3865.23       6508.50     10007.650      3070.46
# 2025-10-15 15:00      3912.21       6592.56     10147.180      3073.75
# 2025-10-16 15:00      3916.23       6521.60     10153.790      3105.37
# 2025-10-17 15:00      3839.76       6336.26      9938.040      3094.74
# 2025-10-20 15:00      3863.89       6377.18      9956.059      3118.07
# 2025-10-21 15:00      3916.33       6459.09     10087.941      3111.68
# 2025-10-22 15:00      3913.76       6407.66     10050.741      3116.25
# 2025-10-23 15:00      3922.41       6413.36     10080.400      3141.51
# 2025-10-24 15:00      3950.31       6493.97     10178.380      3116.77
# 2025-10-27 15:00      3996.94       6573.38     10317.481      3128.61
# 2025-11-03 15:00  2008.033081  3278.698730   850.785400  1447.463501
# 2025-11-04 15:00  2003.362427  3241.603516   848.053711  1427.638184
# 2025-11-05 15:00  2004.361694  3223.287109   856.835876  1434.887573
# 2025-11-06 15:00  2031.562256  3254.627197   844.336182  1460.667114
# 2025-11-07 15:00  2033.789673  3211.288574   840.742981  1481.486572
# 2025-11-10 15:00  2054.422852  3206.520508   856.510315  1507.824951
# 2025-11-11 15:00  2040.301514  3146.711426   853.538879  1514.753784
# 2025-11-12 15:00  2032.265869  3117.683838   851.993591  1518.087158
# 2025-11-13 15:00  2047.042114  3157.342285   854.554199  1541.894043
# 2025-11-14 15:00  2018.013916  3066.906006   847.262329  1527.095947
#
# [30 rows x 1620 columns]

# %%
dfI.drop('2025-10-08 15:00').to_excel('/home/ts/app/AiStock/Linkage/MergIndex.xlsx')

# %%
dfI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6305 entries, 2000-05-15 15:00 to 2025-11-14 15:00
# Columns: 1620 entries, 000001:上证指数 to H50055:沪大农业
# dtypes: float64(1619), object(1)
# memory usage: 78.1+ MB

# %%
psDFI = dfI.corr()

# %%
psDFI.to_excel('/home/ts/app/AnaStock/psIndex.xlsx')

# %%
dfS = pd.DataFrame()
for code in tqdm(StockList):
    try:
        df_tmp = pd.read_sql(code[0], engS).set_index('datetime')['close'].to_frame()
        df_tmp['close'] = np.log(df_tmp['close']  / df_tmp['close'].shift(1))
        df_tmp.rename(columns={'close':code[0]+':'+code[1]}, inplace=True)
        dfS = pd.merge(dfS,df_tmp,right_index=True, left_index=True,how='outer')
    except:
        pass
        print(code+' pass ! ')

# %%
ddf = dfS.round(5).copy()

# %%
ddf

# %%
dfS.to_excel('/home/ts/app/AnaStock/MergStock.xlsx')

# %%
psDFS = dfS.corr()

# %%
psDFS.to_excel('/home/ts/app/AnaStock/psStock.xlsx')

# %%
df.iloc[:,4500:].to_sql('Merg9Stock', engS)

# %% [markdown]
# 步骤1：计算对数收益率

# %%
df['Log_Return'] = np.log(df['close']  / df['close'].shift(1))

# %% [markdown]
# 步骤2：计算波动率（年化）

# %%
daily_volatility = df['Log_Return'].std()  # 日波动率
annual_volatility = daily_volatility * np.sqrt(252)   # 年化波动率

# %% [markdown]
# 步骤3：计算夏普比率

# %%
# 计算平均日对数收益率
daily_mean_return = df['Log_Return'].mean()

# 年化平均收益率（注意：由于对数收益率的可加性，年化收益率可以直接用日平均乘以252，但严格来说，对数收益率的年化应该是日平均乘以252，然后年化波动率是日波动率乘以根号252）
annualized_return = daily_mean_return * 252

# 假设无风险利率为0（或者用户提供）
risk_free_rate = 0.0245  # 这里假设为0，实际应用中需要根据情况调整

# 计算夏普比率
sharpe_ratio = (annualized_return - risk_free_rate) / annual_volatility

# %% [markdown]
# 日波动率

# %%
def parkinson_volatility(high, low):
    ratio = high / low 
    log_hl = np.log(ratio) 
    return np.sqrt(1/(4*np.log(2))) * log_hl  # 百分比形式

# %%
(parkinson_volatility(df['high'], df['low'])* np.sqrt(252)).mean()

# %%
np.sqrt(1/(4*np.log(2)))
